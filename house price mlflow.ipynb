# %% [markdown]
# # Serving models to Mlflow

# %%
import os
# Set the MLflow tracking URI environment variable to a local file path
os.environ['MLFLOW_TRACKING_URI']='file:///Users/sravanthi/OneDrive/Desktop/internship'

# %%
import mlflow
# Search for all runs across all experiments
all_runs=mlflow.search_runs(search_all_experiments=True)
print(all_runs)
# Out:
#                               run_id       experiment_id    status  \
# 0   25ffd8c8b9314126b682f5bec04343cb  271739027587939372  FINISHED
# 1   a38bf06b71a84572b362077d6b1685f4  271739027587939372  FINISHED
# 2   7613c62393f24ea28a52befcd3849b30  271739027587939372    FAILED
# 3   bf62bf3aa65a448f90d90cad5a6fb379  271739027587939372    FAILED
# 4   bd058b195c0146b3be887b8399e1adf2  446115915831014354  FINISHED
# 5   22a7833d1e3648adb44cc8b98c93912e  446115915831014354    FAILED
# 6   7238d9dcff044e54939eb3393435d3d1  446115915831014354  FINISHED
# 7   8e5be8f4c2de4dd89a806282900a9cdb  446115915831014354    FAILED
# 8   f6e089c72f2441a2b969aafe22502ab0  598837886088653985  FINISHED
# 9   ea6c1aa41c2b48e5b4cc3aa897c7fd44  598837886088653985  FINISHED
# 10  aaabd108fab842b0919b3915c9ca8870  598837886088653985  FINISHED
# 11  fa6942b9eb6c4f3e954003a811145c63  398777774495770654  FINISHED
# 12  720ac053c01a4cb4bdc6ae8386460566  398777774495770654  FINISHED
# ...

# %%
# !mlflow models serve -p 8180 -m runs:/a38bf06b71a84572b362077d6b1685f4/random-forest-model --no-conda
